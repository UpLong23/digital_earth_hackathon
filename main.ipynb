# %%
import openeo

connection = openeo.connect("https://openeo.dataspace.copernicus.eu")

connection.authenticate_oidc()
# Out:
# Authenticated using refresh token.
# <Connection to 'https://openeo.dataspace.copernicus.eu/openeo/1.2/' with OidcBearerAuth>

# %%
from rich import print

# print(connection.list_collections())

# %% [markdown]
# Digital terain model. Dynamic, connect figures with the data. LPIS forest agency (crop database). National Landcover Database (agricultural coverage)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2026-06-04T19-15_export.csv')

df['Crop'].unique()
# Out:
# array(['Ley / Grass', 'Spring Barley', 'Winter Wheat', 'Rapeseed',
#        'Winter Barley', 'Sugar Beet', 'Maize', 'Fallow', 'Spring Wheat',
#        'Potato', 'Unknown', 'Oats', 'Peas', 'Rye'], dtype=object)

# %%
import xarray as xr
